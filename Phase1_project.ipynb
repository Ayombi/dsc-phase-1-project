# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayombi/dsc-phase-1-project/blob/master/Phase1_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PHASE 1 PROJECT
# MICROSOFT NEW MOVIE STUDIO PROPOSAL - FILMS

# %%
#Importing relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import the data
df1 = pd.read_csv('/bom.movie_gross.csv')
df2 = pd.read_csv('/title.basics.csv')
df3 = pd.read_csv('/title.ratings.csv')

# %%
#preview of 1st  dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df1.shape
# Out:
# (3387, 5)

# %%
#preview of 2nd  dataframe
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   title            146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df2.shape
# Out:
# (146144, 6)

# %%
#preview of 3rd dataframe
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df3.shape
# Out:
# (73856, 3)

# %%
merged_df = pd.merge(df1, df2, on='title', how='right', suffixes=('_left', '_right'))
merged_df.head()
# Out:
#                              title studio  domestic_gross foreign_gross  year  \
# 0                        Sunghursh    NaN             NaN           NaN   NaN
# 1  One Day Before the Rainy Season    NaN             NaN           NaN   NaN
# 2       The Other Side of the Wind    NaN             NaN           NaN   NaN
# 3                  Sabse Bada Sukh    NaN             NaN           NaN   NaN
# 4         The Wandering Soap Opera    NaN             NaN           NaN   NaN
#
#       tconst              original_title  start_year  runtime_minutes  \
# 0  tt0063540                   Sunghursh        2013            175.0
# 1  tt0066787             Ashad Ka Ek Din        2019            114.0
# 2  tt0069049  The Other Side of the Wind        2018            122.0
# 3  tt0069204             Sabse Bada Sukh        2018              NaN
# 4  tt0100275       La Telenovela Errante        2017             80.0
#
#                  genres
# 0    Action,Crime,Drama
# 1       Biography,Drama
# ...

# %%
#merging and confirming merging of the dataframes
final_df = pd.merge(merged_df, df3, on='tconst', how='right', suffixes=('_left', '_right'))
final_df.head()
# Out:
#                     title studio  domestic_gross foreign_gross    year  \
# 0        Laiye Je Yaarian    NaN             NaN           NaN     NaN
# 1              Borderless    NaN             NaN           NaN     NaN
# 2               Just Inès    NaN             NaN           NaN     NaN
# 3  The Legend of Hercules   LG/S      18800000.0      42400000  2014.0
# 4               Até Onde?    NaN             NaN           NaN     NaN
#
#        tconst          original_title  start_year  runtime_minutes  \
# 0  tt10356526        Laiye Je Yaarian        2019            117.0
# 1  tt10384606              Borderless        2019             87.0
# 2   tt1042974               Just Inès        2010             90.0
# 3   tt1043726  The Legend of Hercules        2014             99.0
# 4   tt1060240               Até Onde?        2011             73.0
#
#                      genres  averagerating  numvotes
# 0                   Romance            8.3        31
# ...

# %%
#understanding of the merged data frame- summary of the meta data and characteristics
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           3022 non-null   object
#  2   domestic_gross   3003 non-null   float64
#  3   foreign_gross    1831 non-null   object
#  4   year             3025 non-null   float64
#  5   tconst           73858 non-null  object
#  6   original_title   73858 non-null  object
#  7   start_year       73858 non-null  int64
#  8   runtime_minutes  66238 non-null  float64
#  9   genres           73054 non-null  object
#  10  averagerating    73858 non-null  float64
#  11  numvotes         73858 non-null  int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 7.3+ MB

# %%
final_df.shape
# Out:
# (73858, 12)

# %%
final_df.describe()
# Out:
#        domestic_gross         year    start_year  runtime_minutes  \
# count    3.003000e+03  3025.000000  73858.000000     66238.000000
# mean     3.066073e+07  2014.077686   2014.276138        94.654428
# std      6.673382e+07     2.441833      2.614804       208.570981
# min      1.000000e+02  2010.000000   2010.000000         3.000000
# 25%      1.420000e+05  2012.000000   2012.000000        81.000000
# 50%      2.000000e+06  2014.000000   2014.000000        91.000000
# 75%      3.250000e+07  2016.000000   2016.000000       104.000000
# max      7.001000e+08  2018.000000   2019.000000     51420.000000
#
#        averagerating      numvotes
# count   73858.000000  7.385800e+04
# mean        6.332726  3.523584e+03
# std         1.474959  3.029362e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
#Get data frame information
print(final_df.info)
# Out:
# <bound method DataFrame.info of                                                    title studio  \
# 0                                       Laiye Je Yaarian    NaN
# 1                                             Borderless    NaN
# 2                                              Just Inès    NaN
# 3                                 The Legend of Hercules   LG/S
# 4                                              Até Onde?    NaN
# ...                                                  ...    ...
# 73853                                              Caisa    NaN
# 73854  Code Geass: Lelouch of the Rebellion - Glorifi...    NaN
# 73855                                            Sisters   Uni.
# 73856                                  The Projectionist    NaN
# 73857                                             Sathru    NaN
#
#        domestic_gross foreign_gross    year      tconst  \
# 0                 NaN           NaN     NaN  tt10356526
# ...

# %% [markdown]
# # **Processing the merged data**
# This will include :
#
# 1.   Cleaning and scrubbing
# 2.   Handling missing values

# %%
#DATA CLEANING
# missing values
# duplicates
# outliers
# Unnecessary Data

# Duplicates
final_df.duplicated().value_counts()
#No duplicates
# Out:
# False    73858
# dtype: int64

# %%
# missing values
final_df.isna().sum()
# Out:
# title                  0
# studio             70836
# domestic_gross     70855
# foreign_gross      72027
# year               70833
# tconst                 0
# original_title         0
# start_year             0
# runtime_minutes     7620
# genres               804
# averagerating          0
# numvotes               0
# dtype: int64

# %%
# handle the missing data
# ways to handle missing data
# drop, keep, impute (replace the missing value)
# impute with mean, median
# normal distribution - mean
# skewed distribution or have outliers - median

# %%
#Studio
#proportion of the missing data >5%
sns.histplot(final_df['studio'])
plt.title('distribution curve for studio before cleaning')
# Out:
# Text(0.5, 1.0, 'distribution curve for studio before cleaning')

# %%
#domestic_gross
#proportion of the missing data >5%
sns.histplot(final_df['domestic_gross'])
plt.title('distribution curve for domestic_gross before cleaning')
# The distribution is positively skewed
# Out:
# Text(0.5, 1.0, 'distribution curve for domestic_gross before cleaning')

# %%
#foreign_gross
#proportion of the missing data >5%
sns.histplot(final_df['foreign_gross'], kde= True)
plt.title('distribution curve for foreign_gross before cleaning')
# The distribution is positively skewed
# Out:
# Text(0.5, 1.0, 'distribution curve for foreign_gross before cleaning')

# %%
#Year
#proportion of the missing data >5%
sns.histplot(final_df['year'], kde = True)
plt.title('distribution curve for year before cleaning')
# The distribution is positively skewed
# Out:
# Text(0.5, 1.0, 'distribution curve for year before cleaning')

# %%
#runtime_minutes
#proportion of the missing data >5%
plt.figure(figsize=(5, 10))
sns.histplot(final_df['runtime_minutes'], kde = True)
plt.title('distribution curve for runtime_minutes  before cleaning')
# The distribution is positively skewed
# Out:
# Text(0.5, 1.0, 'distribution curve for runtime_minutes  before cleaning')

# %%
#Unnecessary data
#We note that start_year is the same as year, therefore, we shall drop the column 'year'
final_df.drop('year',axis =1, inplace=True)
final_df.head()
# Out:
#                     title studio  domestic_gross foreign_gross      tconst  \
# 0        Laiye Je Yaarian    NaN             NaN           NaN  tt10356526
# 1              Borderless    NaN             NaN           NaN  tt10384606
# 2               Just Inès    NaN             NaN           NaN   tt1042974
# 3  The Legend of Hercules   LG/S      18800000.0      42400000   tt1043726
# 4               Até Onde?    NaN             NaN           NaN   tt1060240
#
#            original_title  start_year  runtime_minutes  \
# 0        Laiye Je Yaarian        2019            117.0
# 1              Borderless        2019             87.0
# 2               Just Inès        2010             90.0
# 3  The Legend of Hercules        2014             99.0
# 4               Até Onde?        2011             73.0
#
#                      genres  averagerating  numvotes
# 0                   Romance            8.3        31
# 1               Documentary            8.9       559
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           3022 non-null   object
#  2   domestic_gross   3003 non-null   float64
#  3   foreign_gross    1831 non-null   object
#  4   tconst           73858 non-null  object
#  5   original_title   73858 non-null  object
#  6   start_year       73858 non-null  int64
#  7   runtime_minutes  66238 non-null  float64
#  8   genres           73054 non-null  object
#  9   averagerating    73858 non-null  float64
#  10  numvotes         73858 non-null  int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 6.8+ MB

# %%
#genres and studio are categorical data and therefore, we shall fill in the missing values with a string 'Nan' to show the values are missing
final_df['genres'].fillna('Nan', inplace=True)
final_df['studio'].fillna('Nan', inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           73858 non-null  object
#  2   domestic_gross   3003 non-null   float64
#  3   foreign_gross    1831 non-null   object
#  4   tconst           73858 non-null  object
#  5   original_title   73858 non-null  object
#  6   start_year       73858 non-null  int64
#  7   runtime_minutes  66238 non-null  float64
#  8   genres           73858 non-null  object
#  9   averagerating    73858 non-null  float64
#  10  numvotes         73858 non-null  int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 6.8+ MB

# %%
#domestic_gross
# We'll impute using the median because of the positive skewness of the distribution and the many missing  values.We will however not drop the column as domestic gross is key in the box office performance
# using the fillna function
final_df['domestic_gross'].fillna(final_df['domestic_gross'].median(), inplace =True)

# %%
#Despite the fact the foreign gross is a key indficator in the movie performance, we will drop the column
final_df.drop('foreign_gross', axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           73858 non-null  object
#  2   domestic_gross   73858 non-null  float64
#  3   tconst           73858 non-null  object
#  4   original_title   73858 non-null  object
#  5   start_year       73858 non-null  int64
#  6   runtime_minutes  66238 non-null  float64
#  7   genres           73858 non-null  object
#  8   averagerating    73858 non-null  float64
#  9   numvotes         73858 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 6.2+ MB

# %%
#runtime_minutes
#There appears to be some outliers due to the histogram plot. Lets plot a box plot
sns.boxplot(final_df['runtime_minutes'])
plt.title("Box plot of runtime_minutes")
# Out:
# Text(0.5, 1.0, 'Box plot of runtime_minutes')

# %%
# drop outside the bounds
# Q1 = 25%
# Q2 = 50%
# Q3 = 75%
# Q4 = 100%
# IQR = Q3 -Q1
Q1 = final_df['runtime_minutes'].quantile(0.25)
Q3 = final_df['runtime_minutes'].quantile(0.75)
IQR = Q3 - Q1

#Creating the upper and lower bounds
upper_bound = Q3 + 1.5*IQR
lower_bound = Q1 - 1.5*IQR

# %%
# drop any outliers
#using .clip function

final_df['runtime_minutes'] = final_df['runtime_minutes'].clip(lower = lower_bound, upper = upper_bound)

# %%
# plotting after dropping outliers
sns.boxplot(final_df['runtime_minutes'])
plt.title('Plot of runtime_minutes after dropping the Outliers')
# Out:
# Text(0.5, 1.0, 'Plot of runtime_minutes after dropping the Outliers')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           73858 non-null  object
#  2   domestic_gross   73858 non-null  float64
#  3   tconst           73858 non-null  object
#  4   original_title   73858 non-null  object
#  5   start_year       73858 non-null  int64
#  6   runtime_minutes  66238 non-null  float64
#  7   genres           73858 non-null  object
#  8   averagerating    73858 non-null  float64
#  9   numvotes         73858 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 6.2+ MB

# %%
sns.histplot(final_df['runtime_minutes'], kde = True)
plt.title('distribution curve for runtime_minutes  after removing outliers')
# Out:
# Text(0.5, 1.0, 'distribution curve for runtime_minutes  before cleaning')

# %%
#runtime_minutes distribution is now symmetricakl therefore we shall impute the missing values using the mean
final_df['runtime_minutes'].fillna(final_df['runtime_minutes'].mean(), inplace =True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73858 entries, 0 to 73857
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            73858 non-null  object
#  1   studio           73858 non-null  object
#  2   domestic_gross   73858 non-null  float64
#  3   tconst           73858 non-null  object
#  4   original_title   73858 non-null  object
#  5   start_year       73858 non-null  int64
#  6   runtime_minutes  73858 non-null  float64
#  7   genres           73858 non-null  object
#  8   averagerating    73858 non-null  float64
#  9   numvotes         73858 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 6.2+ MB

# %% [markdown]
# **Describe data**
# Use data exploration, visualizations (at least 5 different kinds), distributions, and discussed the distributions as pertaining to the given dataset.

# %%
#generate descriptive data
print(final_df.describe())
# Out:
#        domestic_gross    start_year  runtime_minutes  averagerating  \
# count    7.385800e+04  73858.000000     73858.000000   73858.000000
# mean     3.165319e+06   2014.276138        92.861092       6.332726
# std      1.459640e+07      2.614804        19.224802       1.474959
# min      1.000000e+02   2010.000000        46.500000       1.000000
# 25%      2.000000e+06   2012.000000        83.000000       5.500000
# 50%      2.000000e+06   2014.000000        92.861092       6.500000
# 75%      2.000000e+06   2016.000000       101.000000       7.400000
# max      7.001000e+08   2019.000000       138.500000      10.000000
#
#            numvotes
# count  7.385800e+04
# mean   3.523584e+03
# std    3.029362e+04
# min    5.000000e+00
# 25%    1.400000e+01
# 50%    4.900000e+01
# 75%    2.820000e+02
# max    1.841066e+06

# %%
# Analyze the distribution of domestic_gross,  start_year , runtime_minutes,averagerating and numvotes   with respect to title

# %%
final_df.groupby(['domestic_gross']).head(10)
# Out:
#                         title studio  domestic_gross      tconst  \
# 0            Laiye Je Yaarian    Nan       2000000.0  tt10356526
# 1                  Borderless    Nan       2000000.0  tt10384606
# 2                   Just Inès    Nan       2000000.0   tt1042974
# 3      The Legend of Hercules   LG/S      18800000.0   tt1043726
# 4                   Até Onde?    Nan       2000000.0   tt1060240
# ...                       ...    ...             ...         ...
# 73550              Boy Erased  Focus       6800000.0   tt7008872
# 73570               Let Me In  Over.      12100000.0   tt7122852
# 73602             The Silence   MBox        100000.0   tt7315484
# 73802         The Negotiation     CJ        111000.0   tt9042690
# 73855                 Sisters   Uni.      87000000.0   tt9851050
#
#                original_title  start_year  runtime_minutes  \
# 0            Laiye Je Yaarian        2019       117.000000
# 1                  Borderless        2019        87.000000
# ...

# %%
final_df.groupby(['averagerating']).head(10)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                    Laiye Je Yaarian    Nan       2000000.0
# 1                                          Borderless    Nan       2000000.0
# 2                                           Just Inès    Nan       2000000.0
# 3                              The Legend of Hercules   LG/S      18800000.0
# 4                                           Até Onde?    Nan       2000000.0
# ...                                               ...    ...             ...
# 45660                                     Freie Räume    Nan       2000000.0
# 45662  Exteriores: Mulheres Brasileiras na Diplomacia    Nan       2000000.0
# 47798                       Dog Days in the Heartland    Nan       2000000.0
# 49075                 Fly High: Story of the Disc Dog    Nan       2000000.0
# 63151               Once Upon a Time ... in Hollywood    Nan       2000000.0
#
# ...

# %%
final_df.groupby(['numvotes']).head(10)
# Out:
#                                     title studio  domestic_gross      tconst  \
# 0                        Laiye Je Yaarian    Nan       2000000.0  tt10356526
# 1                              Borderless    Nan       2000000.0  tt10384606
# 2                               Just Inès    Nan       2000000.0   tt1042974
# 3                  The Legend of Hercules   LG/S      18800000.0   tt1043726
# 4                               Até Onde?    Nan       2000000.0   tt1060240
# ...                                   ...    ...             ...         ...
# 73765                             Dear Ex    Nan       2000000.0   tt8443704
# 73773                   Death of a Nation    Nan       2000000.0   tt8564902
# 73774  The Witch: Part 1 - The Subversion    Nan       2000000.0   tt8574252
# 73794                              Jersey    Nan       2000000.0   tt8948790
# 73833                    PM Narendra Modi    Nan       2000000.0   tt9558612
#
# ...

# %%
final_df.groupby(['start_year']).mean().head(10)
# Out:
# <ipython-input-159-6c73332dab3e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df.groupby(['start_year']).mean().head(10)
#             domestic_gross  runtime_minutes  averagerating     numvotes
# start_year
# 2010          3.440262e+06        91.708335       6.259585  4488.480418
# 2011          3.285841e+06        91.553392       6.290134  4431.113953
# 2012          3.173181e+06        91.198261       6.297032  4260.686629
# 2013          3.270134e+06        91.795402       6.287259  4460.397622
# 2014          3.109701e+06        92.561689       6.319806  4107.310238
# 2015          3.001025e+06        92.696146       6.265894  3080.688721
# 2016          3.295263e+06        93.010949       6.347300  3052.597523
# ...

# %%
sns.histplot(final_df['studio'])
plt.title('distribution curve for studio')
# Out:
# Text(0.5, 1.0, 'distribution curve for studio')

# %%
sns.histplot(final_df['domestic_gross'])
plt.title('distribution curve for domestic_gross')
# Out:
# Text(0.5, 1.0, 'distribution curve for domestic_gross')

# %%
sns.histplot(final_df['averagerating'])
plt.title('distribution curve for daveragerating')
# Out:
# Text(0.5, 1.0, 'distribution curve for daveragerating')

# %%
sns.histplot(final_df['numvotes'])
plt.title('distribution curve for numvotes')
# Out:
# Text(0.5, 1.0, 'distribution curve for numvotes')

# %%
#Bivariate Analysis:
#Investigate relationships between pairs of variables. For instance, explore how box office revenue correlates with budget or how ratings relate to the release year.

# %%
#Bivariate Analysis
# ratings relate to the release year.
